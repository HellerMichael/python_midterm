# %% [markdown]
# Michael Heller

# %% [markdown]
# ### Part I

# %%
import numpy as np
import pandas as pd 
import requests
from bs4 import BeautifulSoup
import pandas as pd
import tqdm as tqdm
from lxml import html
import time

# %%
def getSoup_test(link):
        r = requests.get(link)
        r.encoding = 'UTF-8'
        return BeautifulSoup(r.text, 'html')

# %%
my_data = getSoup_test('https://en.wikipedia.org/wiki/FTSE_100_Index')

# %%
my_data.text
# Out:
# '\n\n\nFTSE 100 Index - Wikipedia\ndocument.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"e96e2f54-8a8e-4d38-ab24-e138cf41612a","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"FTSE_100_Index","wgTitle":"FTSE 100 Index","wgCurRevisionId":989050793,"wgRevisionId":989050793,"wgArticleId":497717,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Webarchive template wayback links","All articles with dead external links","Articles with dead external links from December 2016","Articles with permanently dead external links","Articles with dead external links from February 2019","CS1: Julian–Gregorian uncertainty",\n"Ar
# ...

# %%
my_data.find('table', {'id': 'constituents'}).findAll('tbody')
# Out:
# [<tbody><tr>
#  <th>Company</th>
#  <th>EPIC</th>
#  <th>FTSE Industry Classification Benchmark sector<sup class="reference" id="cite_ref-12"><a href="#cite_note-12">[12]</a></sup>
#  </th></tr>
#  <tr>
#  <td><a href="/wiki/3i" title="3i">3i</a></td>
#  <td>III</td>
#  <td>Financial Services
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Admiral_Group" title="Admiral Group">Admiral Group</a></td>
#  <td>ADM</td>
#  <td>Nonlife Insurance
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Anglo_American_plc" title="Anglo American plc">Anglo American plc</a></td>
#  <td>AAL</td>
#  <td>Mining
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Antofagasta_PLC" title="Antofagasta PLC">Antofagasta</a></td>
#  <td>ANTO</td>
#  <td>Mining
#  </td></tr>
#  <tr>
#  <td><a href="/wiki/Ashtead_Group" title="Ashtead Group">Ashtead Group</a></td>
#  <td>AHT</td>
#  <td>Support Services
#  </td></tr>
#  <tr>
# ...

# %%
table = my_data.find('table', {'id': 'constituents'}).find('tbody').findAll('tr')
table
# Out:
# [<tr>
#  <th>Company</th>
#  <th>EPIC</th>
#  <th>FTSE Industry Classification Benchmark sector<sup class="reference" id="cite_ref-12"><a href="#cite_note-12">[12]</a></sup>
#  </th></tr>, <tr>
#  <td><a href="/wiki/3i" title="3i">3i</a></td>
#  <td>III</td>
#  <td>Financial Services
#  </td></tr>, <tr>
#  <td><a href="/wiki/Admiral_Group" title="Admiral Group">Admiral Group</a></td>
#  <td>ADM</td>
#  <td>Nonlife Insurance
#  </td></tr>, <tr>
#  <td><a href="/wiki/Anglo_American_plc" title="Anglo American plc">Anglo American plc</a></td>
#  <td>AAL</td>
#  <td>Mining
#  </td></tr>, <tr>
#  <td><a href="/wiki/Antofagasta_PLC" title="Antofagasta PLC">Antofagasta</a></td>
#  <td>ANTO</td>
#  <td>Mining
#  </td></tr>, <tr>
#  <td><a href="/wiki/Ashtead_Group" title="Ashtead Group">Ashtead Group</a></td>
#  <td>AHT</td>
#  <td>Support Services
#  </td></tr>, <tr>
#  <td><a href="/wiki/Associated_British_Foods" title="Associated British Foods">Associated British Foods</a></td>
# ...

# %%
company_ticker = [i.findChild().text for i in table]
company_ticker
# Out:
# ['Company',
#  '3i',
#  'Admiral Group',
#  'Anglo American plc',
#  'Antofagasta',
#  'Ashtead Group',
#  'Associated British Foods',
#  'AstraZeneca',
#  'Auto Trader Group',
#  'Avast',
#  'Aveva',
#  'Aviva',
#  'B&M',
#  'BAE Systems',
#  'Barclays',
#  'Barratt Developments',
#  'Berkeley Group Holdings',
#  'BHP',
#  'BP',
#  'British American Tobacco',
#  'British Land',
#  'BT Group',
#  'Bunzl',
#  'Burberry',
#  'Coca-Cola HBC',
#  'Compass Group',
#  'CRH plc',
#  'Croda International',
#  'DCC plc',
#  'Diageo',
#  'Evraz',
#  'Experian',
#  'Ferguson plc',
#  'Flutter Entertainment',
#  'Fresnillo',
#  'GlaxoSmithKline',
#  'Glencore',
#  'GVC Holdings',
#  'Halma',
#  'Hargreaves Lansdown',
#  'Hikma Pharmaceuticals',
#  'Homeserve',
#  'HSBC',
#  'Imperial Brands',
#  'Informa',
#  'InterContinental Hotels Group',
#  'Intermediate Capital Group',
#  'International Airlines Group',
#  'Intertek',
#  'JD Sports',
#  'Johnson Matthey',
#  'Just Eat Takeaway',
# ...

# %%
company_names = [i.findChild().text for i in table]
company_names
# Out:
# ['Company',
#  '3i',
#  'Admiral Group',
#  'Anglo American plc',
#  'Antofagasta',
#  'Ashtead Group',
#  'Associated British Foods',
#  'AstraZeneca',
#  'Auto Trader Group',
#  'Avast',
#  'Aveva',
#  'Aviva',
#  'B&M',
#  'BAE Systems',
#  'Barclays',
#  'Barratt Developments',
#  'Berkeley Group Holdings',
#  'BHP',
#  'BP',
#  'British American Tobacco',
#  'British Land',
#  'BT Group',
#  'Bunzl',
#  'Burberry',
#  'Coca-Cola HBC',
#  'Compass Group',
#  'CRH plc',
#  'Croda International',
#  'DCC plc',
#  'Diageo',
#  'Evraz',
#  'Experian',
#  'Ferguson plc',
#  'Flutter Entertainment',
#  'Fresnillo',
#  'GlaxoSmithKline',
#  'Glencore',
#  'GVC Holdings',
#  'Halma',
#  'Hargreaves Lansdown',
#  'Hikma Pharmaceuticals',
#  'Homeserve',
#  'HSBC',
#  'Imperial Brands',
#  'Informa',
#  'InterContinental Hotels Group',
#  'Intermediate Capital Group',
#  'International Airlines Group',
#  'Intertek',
#  'JD Sports',
#  'Johnson Matthey',
#  'Just Eat Takeaway',
# ...

# %%
table_1 = my_data .find('table', {'id': 'constituents'}).find('tbody').findAll('td')
table_2 = [i.text for i in table_1]

# %%
len(table_2)
# Out:
# 300

# %%
table_3 = table_2.copy

# %%
pd.DataFrame(table_2)
# Out:
#                                          0
# 0                                       3i
# 1                                      III
# 2                     Financial Services\n
# 3                            Admiral Group
# 4                                      ADM
# 5                      Nonlife Insurance\n
# 6                       Anglo American plc
# 7                                      AAL
# 8                                 Mining\n
# 9                              Antofagasta
# 10                                    ANTO
# 11                                Mining\n
# 12                           Ashtead Group
# 13                                     AHT
# 14                      Support Services\n
# 15                Associated British Foods
# 16                                     ABF
# 17                        Food Producers\n
# 18                             AstraZeneca
# 19                                     AZN
# 20       Pharmaceuticals & Biotechnology\n
# ...

# %%
np_array = np.array(table_2)

reshaped_array = np.reshape(np_array, (100, 3))
pd.DataFrame(reshaped_array)
# Out:
#                                      0     1  \
# 0                                   3i   III
# 1                        Admiral Group   ADM
# 2                   Anglo American plc   AAL
# 3                          Antofagasta  ANTO
# 4                        Ashtead Group   AHT
# 5             Associated British Foods   ABF
# 6                          AstraZeneca   AZN
# 7                    Auto Trader Group  AUTO
# 8                                Avast  AVST
# 9                                Aveva   AVV
# 10                               Aviva   AV.
# 11                                 B&M   BME
# 12                         BAE Systems   BA.
# 13                            Barclays  BARC
# 14                Barratt Developments  BDEV
# 15             Berkeley Group Holdings   BKG
# 16                                 BHP   BHP
# 17                                  BP   BP.
# 18            British American Tobacco  BATS
# 19                        British Land  BLND
# ...

# %% [markdown]
# ### Part II
